# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "/Users/ryan/Desktop/bootcamp/homework/hw4_pandas/pandas-challenge/PyCitySchools/Resources/schools_complete.csv"
student_data_to_load = "/Users/ryan/Desktop/bootcamp/homework/hw4_pandas/pandas-challenge/PyCitySchools/Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

#school_data = school_data.rename(columns = {'school_name': 'school'})

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, on=["school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# 1                 94          61          0  District  2917  1910635
# 2                 90          60          0  District  2917  1910635
# 3                 67          58          0  District  2917  1910635
# 4                 97          84          0  District  2917  1910635
# ...              ...         ...        ...       ...   ...      ...
# 39165             99          90         14   Charter  1635  1043130
# 39166             95          70         14   Charter  1635  1043130
# 39167             73          84         14   Charter  1635  1043130
# 39168             99          90         14   Charter  1635  1043130
# 39169             95          75         14   Charter  1635  1043130
#
# [39170 rows x 11 columns]

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate total schools, students, and budget of district
total_schools = school_data["School ID"].count()
total_students = school_data["size"].sum()
total_budget = school_data["budget"].sum()

# Calculate average math and reading scores
avg_math = student_data["math_score"].mean()
avg_reading = student_data["reading_score"].mean()

# Calculate percent passing rates
pass_math = student_data.loc[student_data["math_score"] >= 70]
perc_math = len(pass_math)/total_students *100
pass_read = student_data.loc[student_data["reading_score"] >= 70]
perc_read = len(pass_read)/total_students *100
pass_overall = student_data.loc[(student_data["math_score"] >= 70) & 
                                (student_data["reading_score"] >= 70)]
perc_overall = len(pass_overall)/total_students *100

# Create dataframe for district summary
district_summary_df = pd.DataFrame({"Total Schools": total_schools,
                                "Total Students": total_students,
                                "Total Budget": total_budget,
                                "Average Math Score": avg_math,
                                "Average Reading Score": avg_reading,
                                "% Passing Math": perc_math,
                                "% Passing Reading": perc_read,
                                "% Overall Passing Rate": [perc_overall]})

# Formatting
district_summary_df = district_summary_df[["Total Schools", 
                             "Total Students", 
                             "Total Budget", 
                             "Average Reading Score", 
                             "Average Math Score", 
                             '% Passing Reading', 
                             '% Passing Math', 
                             '% Overall Passing Rate']]
district_summary_df['Total Budget'] = district_summary_df['Total Budget'].map('${:,.2f}'.format)
district_summary_df['Total Students'] = district_summary_df['Total Students'].map("{:,}".format)

##########################################
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget  Average Reading Score  \
# 0             15         39,170  $24,649,428.00               81.87784
#
#    Average Math Score  % Passing Reading  % Passing Math  \
# 0           78.985371          85.805463       74.980853
#
#    % Overall Passing Rate
# 0               65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#groups by school
by_school = school_data_complete.set_index('school_name').groupby(['school_name'])

#school types
sch_types = school_data.set_index('school_name')['type']
# total students by school
students_per_school = by_school["Student ID"].count()
# school budget
school_budget = school_data.set_index("school_name")['budget']
school_size = school_data.set_index("school_name")['size']
#per student budget
stu_budget = school_budget/school_size
#avg scores by school
avg_math_byschool = by_school["math_score"].mean()
avg_reading_byschool = by_school["reading_score"].mean()
# % passing scores
pass_math_byschool = school_data_complete[school_data_complete['math_score'] >= 70].groupby('school_name')['Student ID'].count()/students_per_school
pass_reading_byschool = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('school_name')['Student ID'].count()/students_per_school
pass_overall_byschool = school_data_complete[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)].groupby('school_name')['Student ID'].count()/students_per_school

school_summary = pd.DataFrame({
    "School Type": sch_types,
    "Total Students": students_per_school,
    "Per Student Budget": stu_budget,
    "Total School Budget": school_budget,
    "Average Math Score": avg_math_byschool,
    "Average Reading Score": avg_reading_byschool,
    '% Passing Math': pass_math_byschool,
    '% Passing Reading': pass_reading_byschool,
    "Overall Passing Rate": pass_overall_byschool
})


#formatting
school_summary = school_summary[['School Type', 
                          'Total Students', 
                          'Total School Budget', 
                          'Per Student Budget', 
                          'Average Math Score', 
                          'Average Reading Score',
                          '% Passing Math',
                          '% Passing Reading',
                          'Overall Passing Rate']]



school_summary = school_summary.style.format({'Total Students': '{:,}', 
                          "Total School Budget": "${:,}", 
                          "Per Student Budget": "${:.0f}",
                          'Average Math Score': "{:.1f}", 
                          'Average Reading Score': "{:.1f}", 
                          "% Passing Math": "{:.1%}", 
                          "% Passing Reading": "{:.1%}", 
                          "Overall Passing Rate": "{:.1%}"})
school_summary
# Out:
# <style  type="text/css" >
# </style><table id="T_78c8f094_d47c_11eb_9624_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total School Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >Overall Passing Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_78c8f094_d47c_11eb_9624_acde48001122level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col0" class="data row0 col0" >District</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col1" class="data row0 col1" >4,976</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col2" class="data row0 col2" >$3,124,928</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col3" class="data row0 col3" >$628</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col4" class="data row0 col4" >77.0</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col5" class="data row0 col5" >81.0</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col6" class="data row0 col6" >66.7%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col7" class="data row0 col7" >81.9%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row0_col8" class="data row0 col8" >54.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_78c8f094_d47c_11eb_9624_acde48001122level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col0" class="data row1 col0" >Charter</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col1" class="data row1 col1" >1,858</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col2" class="data row1 col2" >$1,081,356</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col3" class="data row1 col3" >$582</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col4" class="data row1 col4" >83.1</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col5" class="data row1 col5" >84.0</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col6" class="data row1 col6" >94.1%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col7" class="data row1 col7" >97.0%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row1_col8" class="data row1 col8" >91.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_78c8f094_d47c_11eb_9624_acde48001122level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col0" class="data row2 col0" >District</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col1" class="data row2 col1" >2,949</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col2" class="data row2 col2" >$1,884,411</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col3" class="data row2 col3" >$639</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col4" class="data row2 col4" >76.7</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col5" class="data row2 col5" >81.2</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col6" class="data row2 col6" >66.0%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col7" class="data row2 col7" >80.7%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row2_col8" class="data row2 col8" >53.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_78c8f094_d47c_11eb_9624_acde48001122level0_row3" class="row_heading level0 row3" >Ford High School</th>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col0" class="data row3 col0" >District</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col1" class="data row3 col1" >2,739</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col2" class="data row3 col2" >$1,763,916</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col3" class="data row3 col3" >$644</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col4" class="data row3 col4" >77.1</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col5" class="data row3 col5" >80.7</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col6" class="data row3 col6" >68.3%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col7" class="data row3 col7" >79.3%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row3_col8" class="data row3 col8" >54.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_78c8f094_d47c_11eb_9624_acde48001122level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col0" class="data row4 col0" >Charter</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col1" class="data row4 col1" >1,468</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col2" class="data row4 col2" >$917,500</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col3" class="data row4 col3" >$625</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col4" class="data row4 col4" >83.4</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col5" class="data row4 col5" >83.8</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col6" class="data row4 col6" >93.4%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col7" class="data row4 col7" >97.1%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row4_col8" class="data row4 col8" >90.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_78c8f094_d47c_11eb_9624_acde48001122level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col0" class="data row5 col0" >District</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col1" class="data row5 col1" >4,635</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col2" class="data row5 col2" >$3,022,020</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col3" class="data row5 col3" >$652</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col4" class="data row5 col4" >77.3</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col5" class="data row5 col5" >80.9</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col6" class="data row5 col6" >66.8%</td>
#                         <td id="T_78c8f094_d47c_11eb_9624_acde48001122row5_col7" class="data row5 col7" >80.9%</td>

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# Thomas High School               83.848930       93.272171          97.308869
# Griffin High School              83.816757       93.392371          97.138965
# Wilson High School               83.989488       93.867718          96.539641
# Pena High School                 84.044699       94.594595          95.945946
#
#                      % Overall Passing
# Cabrera High School          91.334769
# Thomas High School           90.948012
# Griffin High School          90.599455
# Wilson High School           90.582567
# Pena High School             90.540541

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%